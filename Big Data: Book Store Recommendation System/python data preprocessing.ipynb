# %%
import pandas as pd
import numpy as np

# %%
for i in range(1,20):
    name=str(i)+"00"
    name_1 = str(i+1)+'00'
    file_name = 'book'+name+'k'+'-'+name_1+'k'
    print(file_name)
    file = '/Users/qingyangli/MSBA_COURSES/big_data/goodgood/'+file_name+'.csv'
    df = pd.read_csv(file)
    for j in ['Name','Authors','Publisher','Description','Language']:
        if j in df.columns:
            df[j] = df[j].str.replace(',','')
    save_address = '/Users/qingyangli/MSBA_COURSES/big_data/goodread/cleansed\ data/'+file_name+'.csv'
    df.to_csv(file_name+'.csv')
# Out:
# book100k-200k
# book200k-300k
# book300k-400k
# book400k-500k
# book500k-600k
# book600k-700k
# book700k-800k
# book800k-900k
# book900k-1000k
# book1000k-1100k
# book1100k-1200k
# book1200k-1300k
# book1300k-1400k
# book1400k-1500k
# book1500k-1600k
# book1600k-1700k
# book1700k-1800k
# book1800k-1900k
# book1900k-2000k

# %%
for i in ['book1-100k','book2000k-3000k','book3000k-4000k','book4000k-5000k']:

    file = '/Users/qingyangli/MSBA_COURSES/big_data/goodgood/'+i+'.csv'
    df = pd.read_csv(file)
    for j in ['Name','Authors','Publisher','Description','Language']:
        if j in df.columns:
            df[j] = df[j].str.replace(',','')
    save_address = '/Users/qingyangli/MSBA_COURSES/big_data/goodread/cleansed\ data/'+file_name+'.csv'
    df.to_csv(i+'.csv')

# %%
df
# Out:
#              Id                                               Name  \
# 0       4000000                                     Top Management
# 1       4000001                           Celtic Warfare 1595 1763
# 2       4000002                                   Playwright Power
# 3       4000009                   Selected Topics In Harmonic Maps
# 4       4000010  Foreign Exchange Intervention: Objectives And ...
# ...         ...                                                ...
# 280251  4846443                          About International Trade
# 280252  4846447  International and Global Marketing: Concepts a...
# 280253  4846448                      The Best of Vincent Mulchrone
# 280254  4846449                        Forgive Us Our Press Passes
# 280255  4846451             A Fractography Atlas Of Casting Alloys
#
#                           Authors        ISBN  Rating  PublishYear  \
# 0                 Bernard  Taylor  0582446058    0.00         1973
# ...
